# %% [markdown]
# # Two Number Sum

# %% [markdown]
# Write a function that take in a non-empty array of distinct integers and an integer representing a target sum. If any two numbers in the input array sum up to the target sum, the function should return then in an array, in any order. If no two numbers sum up to the target sum, the function should return an empty array.

# %% [markdown]
# ## Pytest

# %%
# !pip install pytest pytest-sugar
# Out:
# Collecting pytest
#   Downloading pytest-7.1.3-py3-none-any.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 5.1 MB/s eta 0:00:0000:01
# Collecting pytest-sugar
#   Downloading pytest_sugar-0.9.5-py2.py3-none-any.whl (9.0 kB)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting attrs>=19.2.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.2 MB/s eta 0:00:00
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in /Users/morsinaldo/Library/Python/3.10/lib/python/site-packages (from pytest) (21.3)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/site-packages (from pytest-sugar) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/morsinaldo/Library/Python/3.10/lib/python/site-packages (from packaging->pytest) (3.0.9)
# Installing collected packages: iniconfig, tomli, py, pluggy, attrs, pytest, pytest-sugar
# Successfully installed attrs-22.1.0 iniconfig-1.1.1 pluggy-1.0.0 py-1.11.0 pytest-7.1.3 pytest-sugar-0.9.5 tomli-2.0.1

# %%
# %%file test_data_n_2.py
import pytest

def twoNumberSum(array, targetSum):
  """
  Description:
  A function that take in a non-empty array of distinct integers
  and an integer representing a target sum. If any two numbers 
  in the input array sum up to the target sum, the function should
  return then in an array, in any order. 
  If no two numbers sum up to the target sum, 
  the function should return an empty array.

  Parameters:
  array <list>: list of integers
  targetSum <integer>: integer representing a target sum

  Return:
  Interger pair which sum is equal to targetSum
  empty otherwise
  """
  for i in range(len(array) - 1):
    firstNum = array[i]
    for j in range (i+1, len(array)):
      secondNum = array[j]
      if firstNum + secondNum == targetSum:
        return [firstNum, secondNum]
  return []

@pytest.fixture(scope="session")
def data():
    
    array = []
    
    # test 1 data
    array.append([3, 5, -4, 8, 11, 1, -1, 6])

    # test 2 data
    array.append([4, 6, 1, -3])

    # test 3 data
    array.append([1, 2, 3, 4, 5, 6, 7, 8, 9, 15])

    # test 4 data
    array.append([15])

    # test 5 data
    array.append([-21, 301, 12, 4, 65, 56, 210, 356, 9, -47])

    # test 6 data
    array.append([-21, 301, 12, 4, 65, 56, 210, 356, 9, -47])

    # test 7 data
    array.append([-7, -5, -3, -1, 0, 1, 3, 5, 7])
    
    return array

def test_1(data):
    """
    Test evaluation for [3, 5, -4, 8, 11, 1, -1, 6] and target 10
    """
    assert twoNumberSum(data[0],10) == [11,-1]


def test_2(data):
    """
    Test evaluation for [4, 6, 1, -3] and target 3
    """
    assert twoNumberSum(data[1],3) == [6,-3]

def test_3(data):
    """
    Test evaluation for [1, 2, 3, 4, 5, 6, 7, 8, 9, 15] and target 26
    """
    assert twoNumberSum(data[2],26) == []

def test_4(data):
    """
    Test evaluation for [15] and target 15
    """
    assert twoNumberSum(data[3],15) == []

def test_5(data):
    """
    Test evaluation for [-21, 301, 12, 4, 65, 56, 210, 356, 9, -47] and target 164
    """
    assert twoNumberSum(data[4],164) == [] 

def test_6(data):
    """
    Test evaluation for [-21, 301, 12, 4, 65, 56, 210, 356, 9, -47] and target 163
    """
    assert twoNumberSum(data[5],163) == [210, -47] 

def test_7(data):
    """
    Test evaluation for [-7, -5, -3, -1, 0, 1, 3, 5, 7] and target -5
    """
    assert twoNumberSum(data[6],-5) == [-5, 0]

# %%
# !pytest . -vv

# %%
# %%file test_data_n.py
import pytest

def twoNumberSum(array, targetSum):
  """
  Description:
  A function that take in a non-empty array of distinct integers
  and an integer representing a target sum. If any two numbers 
  in the input array sum up to the target sum, the function should
  return then in an array, in any order. 
  If no two numbers sum up to the target sum, 
  the function should return an empty array.

  Parameters:
  array <list>: list of integers
  targetSum <integer>: integer representing a target sum

  Return:
  Interger pair which sum is equal to targetSum
  empty otherwise
  """
  dictionary = {}
  for i in range(len(array)):
    x = array[i]
    y = targetSum - x
    if y not in dictionary:
      dictionary[x] = True
    else:
      return [y,x]
  return []

@pytest.fixture(scope="session")
def data():
    
    array = []
    
    # test 1 data
    array.append([3, 5, -4, 8, 11, 1, -1, 6])

    # test 2 data
    array.append([4, 6, 1, -3])

    # test 3 data
    array.append([1, 2, 3, 4, 5, 6, 7, 8, 9, 15])

    # test 4 data
    array.append([15])

    # test 5 data
    array.append([-21, 301, 12, 4, 65, 56, 210, 356, 9, -47])

    # test 6 data
    array.append([-21, 301, 12, 4, 65, 56, 210, 356, 9, -47])

    # test 7 data
    array.append([-7, -5, -3, -1, 0, 1, 3, 5, 7])
    
    return array

def test_1(data):
    """
    Test evaluation for [3, 5, -4, 8, 11, 1, -1, 6] and target 10
    """
    assert twoNumberSum(data[0],10) == [11,-1]


def test_2(data):
    """
    Test evaluation for [4, 6, 1, -3] and target 3
    """
    assert twoNumberSum(data[1],3) == [6,-3]

def test_3(data):
    """
    Test evaluation for [1, 2, 3, 4, 5, 6, 7, 8, 9, 15] and target 26
    """
    assert twoNumberSum(data[2],26) == []

def test_4(data):
    """
    Test evaluation for [15] and target 15
    """
    assert twoNumberSum(data[3],15) == []

def test_5(data):
    """
    Test evaluation for [-21, 301, 12, 4, 65, 56, 210, 356, 9, -47] and target 164
    """
    assert twoNumberSum(data[4],164) == [] 

def test_6(data):
    """
    Test evaluation for [-21, 301, 12, 4, 65, 56, 210, 356, 9, -47] and target 163
    """
    assert twoNumberSum(data[5],163) == [210, -47] 

def test_7(data):
    """
    Test evaluation for [-7, -5, -3, -1, 0, 1, 3, 5, 7] and target -5
    """
    assert twoNumberSum(data[6],-5) == [-5, 0]
# Out:
# Overwriting test_data_n.py

# %%
# !pytest . -vv
# Out:
# Test session starts (platform: linux, Python 3.7.13, pytest 3.6.4, pytest-sugar 0.9.5)
# cachedir: .pytest_cache
# rootdir: /content, inifile:
# plugins: typeguard-2.7.1, sugar-0.9.5
#
#  test_data_n.py::test_1 ✓                                         14% █▌
#  test_data_n.py::test_2 ✓                                         29% ██▉
#  test_data_n.py::test_3 ✓                                         43% ████▍
#  test_data_n.py::test_4 ✓                                         57% █████▊
#  test_data_n.py::test_5 ✓                                         71% ███████▎
#  test_data_n.py::test_6 ✓                                         86% ████████▋
#  test_data_n.py::test_7 ✓                                        100% ██████████
#
# Results (0.03s):
#        7 passed

# %% [markdown]
# ## Checking Time Complexity

# %%
import time
import random
import matplotlib.pyplot as plt
import numpy as np

def gen_input(length):
    return [random.randint(-1000, 1000) for _ in range(length)]

# %%
# Function with time complexity = O(n^2)
def twoNumberSum(array, targetSum):
  """
  Description:
  A function that take in a non-empty array of distinct integers
  and an integer representing a target sum. If any two numbers 
  in the input array sum up to the target sum, the function should
  return then in an array, in any order. 
  If no two numbers sum up to the target sum, 
  the function should return an empty array.

  Parameters:
  array <list>: list of integers
  targetSum <integer>: integer representing a target sum

  Return:
  Interger pair which sum is equal to targetSum
  empty otherwise
  """
  for i in range(len(array) - 1):
    firstNum = array[i]
    for j in range (i+1, len(array)):
      secondNum = array[j]
      if firstNum + secondNum == targetSum:
        return [firstNum, secondNum]
  return []

# %%
times_O_N_2 = []
for length in range(1,5000):
    values = gen_input(length)
    start = time.time()
    twoNumberSum(values, length)
    end = time.time()
    times_O_N_2.append(end - start)

# %%
plt.style.use('fivethirtyeight')

fig, ax = plt.subplots(1,1,figsize=(10,6))
ax.plot(times_O_N_2,label="Real execution time")
ax.set_xlabel("Array Size")
ax.set_ylabel("Runtime (ms)")

z = np.polyfit(range(1, 5000),times_O_N_2, 2)
p = np.poly1d(z)

ax.plot(range(1, 5000),p(range(1, 5000)),label="Time complexity model")
ax.legend()
plt.show()

# %%
# Function with time complexity = O(n)
def twoNumberSum(array, targetSum):
  """
  Description:
  A function that take in a non-empty array of distinct integers
  and an integer representing a target sum. If any two numbers 
  in the input array sum up to the target sum, the function should
  return then in an array, in any order. 
  If no two numbers sum up to the target sum, 
  the function should return an empty array.

  Parameters:
  array <list>: list of integers
  targetSum <integer>: integer representing a target sum

  Return:
  Interger pair which sum is equal to targetSum
  empty otherwise
  """
  dictionary = {}
  for i in range(len(array)):
    x = array[i]
    y = targetSum - x
    if y not in dictionary:
      dictionary[x] = True
    else:
      return [y,x]
  return []

# %%
times_O_N = []
for length in range(1,5000):
    values = gen_input(length)
    start = time.time()
    twoNumberSum(values, length)
    end = time.time()
    times_O_N.append(end - start)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
ax.plot(times_O_N,label="Real execution time")
ax.set_xlabel("Array Size")
ax.set_ylabel("Runtime (ms)")

z = np.polyfit(range(1, 5000),times_O_N, 1)
p = np.poly1d(z)

ax.plot(range(1, 5000),p(range(1, 5000)),label="Time complexity model")
ax.legend()
plt.show()

# %%
# Comparing between two complexities
fig, ax = plt.subplots(1,1,figsize=(10,6))
ax.plot(times_O_N_2,label="O(n^2)")
ax.set_xlabel("Array Size")
ax.set_ylabel("Runtime (ms)")

ax.plot(times_O_N,label="O(n)")
ax.legend()
plt.show()
